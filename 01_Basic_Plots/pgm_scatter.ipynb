# %%
import matplotlib.pyplot as plt

# %%
study_hrs = [1,2,3,4,5]
marks = [30, 40 , 50 , 90, 100]

# %%
plt.scatter(study_hrs, marks)
plt.xlabel('Study Hours')
plt.ylabel('Marks')
plt.title('Scatter Plot: Study Hours vs Marks')
# Out:
# Text(0.5, 1.0, 'Scatter Plot: Study Hours vs Marks')
