# %%
import matplotlib.pyplot as plt

# %%
name = ['A', 'B', 'C', 'D']
marks = [20, 50, 30, 90]

# %%
plt.bar(name, marks)
plt.xlabel('Student Names')
plt.ylabel('Student Marks')
plt.title('Bar Chart: Student Mark')
# Out:
# Text(0.5, 1.0, 'Bar Chart: Student Mark')
