# %% [markdown]
# PROGRAM FOR DATAFRAME CREATION

# %%
import pandas as pd

# %%
data = {
    'Student':['Arun', 'Arun', 'Meena', 'Meena'],
    'Marks': [70, 80, 75, 85]
}

# %%
data
# Out:
# {'Student': ['Arun', 'Arun', 'Meena', 'Meena'], 'Marks': [70, 80, 75, 85]}

# %%
print(data)
# Out:
# {'Student': ['Arun', 'Arun', 'Meena', 'Meena'], 'Marks': [70, 80, 75, 85]}

# %%
df = pd.DataFrame(data)

# %%
print(df)
# Out:
#   Student  Marks
# 0    Arun     70
# 1    Arun     80
# 2   Meena     75
# 3   Meena     85
