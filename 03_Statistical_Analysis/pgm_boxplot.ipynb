# %%
import matplotlib.pyplot as plt

# %%
data = [20, 30, 40, 90, 99, 100, 10, 20, 30, 40]

# %%
plt.boxplot(data)
plt.title('Boxplot for A List of Numbers')
plt.show()

# %%
import seaborn as sns

# %%
sns.boxplot(data)
plt.title('Boxplot for A List of Numbers')
# Out:
# Text(0.5, 1.0, 'Boxplot for A List of Numbers')
